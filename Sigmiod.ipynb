# %%
# !pip3 install numpy

# %%
import numpy as np

# %%
# !pip3 install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
input = np.arange(-10, 10 , 0.5 ) 
def values(x):
    return 1 / ( 1+ np.exp(-x))

# %%
plt.plot(values(input))
